# %%
from stocker import Stocker

# %%
amazon = Stocker('AMZN')
# Out:
# AMZN Stocker Initialized. Data covers 1997-05-16 to 2018-03-27.
# C:\Users\Rikimaru Tsui\Documents\GitHub\Data-Analysis\stocker\stocker.py:70: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   self.starting_price = float(self.stock.ix[0, 'Adj. Open'])

# %%
amazon.plot_stock()
# Out:
# Maximum Adj. Close = 1598.39 on 2018-03-12.
# Minimum Adj. Close = 1.40 on 1997-05-22.
# Current Adj. Close = 1497.05 on 2018-03-27.

# %%
# predict days into the future
model, model_data = amazon.create_prophet_model(days=90)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Predicted Price on 2018-06-25 = $1879.57
# C:\Users\Rikimaru Tsui\Documents\GitHub\Data-Analysis\stocker\stocker.py:458: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   future.ix[len(future) - 1, 'ds'].date(), future.ix[len(future) - 1, 'yhat']))

# %%
amazon.evaluate_prediction()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\Users\Rikimaru Tsui\Documents\GitHub\Data-Analysis\stocker\stocker.py:522: RuntimeWarning: invalid value encountered in sign
#   test['correct'] = (np.sign(test['pred_diff']) == np.sign(test['real_diff'])) * 1
# C:\Users\Rikimaru Tsui\Documents\GitHub\Data-Analysis\stocker\stocker.py:539: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if (test.ix[i, 'y'] < test.ix[i, 'yhat_upper']) & (test.ix[i, 'y'] > test.ix[i, 'yhat_lower']):
# C:\Users\Rikimaru Tsui\Documents\GitHub\Data-Analysis\stocker\stocker.py:551: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   print('\nPredicted price on {} = ${:.2f}.'.format(max(future['ds']).date(), future.ix[len(future) - 1, 'yhat']))
# Prediction Range: 2017-03-27 to 2018-03-27.
#
# Predicted price on 2018-03-24 = $1054.94.
# Actual price on    2018-03-23 = $1495.56.
#
# Average Absolute Error on Training Data = $16.86.
# Average Absolute Error on Testing  Data = $138.46.
#
# When the model predicted an increase, the price increased 56.41% of the time.
# When the model predicted a  decrease, the price decreased  40.22% of the time.
#
# The actual value was within the 80% confidence interval 59.84% of the time.

# %%
# changepoint priors is the list of changepoints to evaluate
amazon.changepoint_prior_analysis(changepoint_priors=[0.001, 0.05, 0.1, 0.2])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
amazon.changepoint_prior_validation(start_date='2016-01-04', end_date='2017-01-03', changepoint_priors=[0.001, 0.05, 0.1, 0.2])
# Out:
# Validation Range 2016-01-04 to 2017-01-03.
# C:\Users\Rikimaru Tsui\Documents\GitHub\Data-Analysis\stocker\stocker.py:927: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   results.ix[i, 'cps'] = prior
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
#      cps  train_err  train_range    test_err  test_range
# 0  0.001  44.476286   152.723207  149.378762  152.622019
# 1  0.050  11.211444    35.844725  148.306555  134.785826
# 2  0.100  10.688326    34.564745  149.458035  179.523000
# 3  0.200   9.816318    32.129125  125.815115  317.744979

# %%
amazon.changepoint_prior_scale = 0.5

# %%
amazon.evaluate_prediction()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\Users\Rikimaru Tsui\Documents\GitHub\Data-Analysis\stocker\stocker.py:522: RuntimeWarning: invalid value encountered in sign
#   test['correct'] = (np.sign(test['pred_diff']) == np.sign(test['real_diff'])) * 1
# C:\Users\Rikimaru Tsui\Documents\GitHub\Data-Analysis\stocker\stocker.py:539: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if (test.ix[i, 'y'] < test.ix[i, 'yhat_upper']) & (test.ix[i, 'y'] > test.ix[i, 'yhat_lower']):
# C:\Users\Rikimaru Tsui\Documents\GitHub\Data-Analysis\stocker\stocker.py:551: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   print('\nPredicted price on {} = ${:.2f}.'.format(max(future['ds']).date(), future.ix[len(future) - 1, 'yhat']))
# Prediction Range: 2017-03-27 to 2018-03-27.
#
# Predicted price on 2018-03-24 = $1000.45.
# Actual price on    2018-03-23 = $1495.56.
#
# Average Absolute Error on Training Data = $10.86.
# Average Absolute Error on Testing  Data = $177.41.
#
# When the model predicted an increase, the price increased 59.73% of the time.
# When the model predicted a  decrease, the price decreased  45.45% of the time.
#
# The actual value was within the 80% confidence interval 86.75% of the time.

# %%
# Going big 
amazon.evaluate_prediction(nshares=1000)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# C:\Users\Rikimaru Tsui\Documents\GitHub\Data-Analysis\stocker\stocker.py:522: RuntimeWarning: invalid value encountered in sign
#   test['correct'] = (np.sign(test['pred_diff']) == np.sign(test['real_diff'])) * 1
# C:\Users\Rikimaru Tsui\Documents\GitHub\Data-Analysis\stocker\stocker.py:539: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if (test.ix[i, 'y'] < test.ix[i, 'yhat_upper']) & (test.ix[i, 'y'] > test.ix[i, 'yhat_lower']):
# C:\Users\Rikimaru Tsui\Documents\GitHub\Data-Analysis\stocker\stocker.py:608: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   prediction_profit.append(nshares * test_pred_increase.ix[i, 'real_diff'])
# C:\Users\Rikimaru Tsui\Documents\GitHub\Data-Analysis\stocker\stocker.py:613: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_pred_increase['pred_profit'] = prediction_profit
# C:\Users\Rikimaru Tsui\Documents\GitHub\Data-Analysis\stocker\stocker.py:617: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#